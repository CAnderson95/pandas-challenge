# %%
import os
import pandas as pd

# %%
source_csv = "Resources/purchase_data.csv"

# %%
purchase_data_df = pd.read_csv(source_csv)

# %%
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
player_count = purchase_data_df["Purchase ID"].count()
player_count
# Out:
# 780

# %%
unique_items = purchase_data_df["Item Name"].nunique()
unique_items
# Out:
# 179

# %%
avg_price = purchase_data_df["Price"].mean()
formatted_avg_price = "${:,.2f}".format(avg_price)
formatted_avg_price
# Out:
# '$3.05'

# %%
purchase_num = purchase_data_df["Item ID"].count()
purchase_num
# Out:
# 780

# %%
total_rev = purchase_data_df["Price"].sum()
formatted_total_rev = "${:,.2f}".format(total_rev)
formatted_total_rev
# Out:
# '$2,379.77'

# %%
summary = [{"Total Players": player_count, "Number of Unique Items": unique_items, "Average Price": formatted_avg_price, "Number of Purchases": purchase_num, "Total Revenue": formatted_total_rev}]
summary_df = pd.DataFrame(summary)
summary_df
# Out:
#    Total Players  Number of Unique Items Average Price  Number of Purchases  \
# 0            780                     179         $3.05                  780
#
#   Total Revenue
# 0     $2,379.77

# %%
non_response_count = len(purchase_data_df[purchase_data_df["Gender"] == "Other / Non-Disclosed"])
non_response_count
# Out:
# 15

# %%
male_count = len(purchase_data_df[purchase_data_df["Gender"] == "Male"])
male_count
# Out:
# 652

# %%
female_count = len(purchase_data_df[purchase_data_df["Gender"] == "Female"])
female_count
# Out:
# 113

# %%
gender_summary = [{"Gender Selection": "Male", "Total": male_count}, {"Gender Selection": "Female", "Total": female_count}, {"Gender Selection": "Other/Non-Disclosed", "Total": non_response_count}]
gender_summary_df = pd.DataFrame(gender_summary)
gender_summary_df
# Out:
#       Gender Selection  Total
# 0                 Male    652
# 1               Female    113
# 2  Other/Non-Disclosed     15

# %%
gpct_summary = gender_summary_df["Total"]/player_count
gender_summary_df["Percentage of Players"] = gpct_summary
gender_summary_df
# Out:
#       Gender Selection  Total  Percentage of Players
# 0                 Male    652               0.835897
# 1               Female    113               0.144872
# 2  Other/Non-Disclosed     15               0.019231

# %%
gender_summary_df = gender_summary_df.style.format({'Percentage of Players': '{:.2%}'})
gender_summary_df
# Out:
# <style  type="text/css" >
# </style><table id="T_61d5793a_bb3b_11ea_9f10_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender Selection</th>        <th class="col_heading level0 col1" >Total</th>        <th class="col_heading level0 col2" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61d5793a_bb3b_11ea_9f10_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row0_col0" class="data row0 col0" >Male</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row0_col1" class="data row0 col1" >652</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row0_col2" class="data row0 col2" >83.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_61d5793a_bb3b_11ea_9f10_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row1_col0" class="data row1 col0" >Female</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row1_col1" class="data row1 col1" >113</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row1_col2" class="data row1 col2" >14.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_61d5793a_bb3b_11ea_9f10_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row2_col0" class="data row2 col0" >Other/Non-Disclosed</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row2_col1" class="data row2 col1" >15</td>
#                         <td id="T_61d5793a_bb3b_11ea_9f10_acde48001122row2_col2" class="data row2 col2" >1.92%</td>
#             </tr>
#     </tbody></table>

# %%
male_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Male",  :]
male_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
male_avg_price = male_data_df["Price"].mean()
formatted_male_avg_price = "${:,.2f}".format(male_avg_price)
formatted_male_avg_price
# Out:
# '$3.02'

# %%
total_male_rev = male_data_df["Price"].sum()
formatted_male_rev = "${:,.2f}".format(total_male_rev)
formatted_male_rev
# Out:
# '$1,967.64'

# %%
#find total number of unique ID's in SN
unique_sn = male_data_df["SN"].nunique()
unique_sn
# Out:
# 484

# %%
male_avg_ppp = total_male_rev/ unique_sn
formatted_male_avg_ppp = "${:,.2f}".format(male_avg_ppp)
formatted_male_avg_ppp
# Out:
# '$4.07'

# %%
female_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Female",  :]
female_data_df.head()
# Out:
#     Purchase ID         SN  Age  Gender  Item ID  \
# 15           15  Lisassa64   21  Female       98
# 18           18  Reunasu60   22  Female       82
# 38           38   Reulae52   10  Female      116
# 41           41  Assosia88   20  Female        7
# 55           55  Phaelap26   25  Female       84
#
#                        Item Name  Price
# 15   Deadline, Voice Of Subtlety   2.89
# 18                       Nirvana   4.90
# 38       Renewed Skeletal Katana   4.18
# 41  Thorn, Satchel of Dark Souls   1.33
# 55                    Arcane Gem   3.79

# %%
female_avg_price = female_data_df["Price"].mean()
formatted_female_avg_price = "${:,.2f}".format(female_avg_price)
formatted_female_avg_price
# Out:
# '$3.20'

# %%
total_female_rev = female_data_df["Price"].sum()
formatted_female_rev = "${:,.2f}".format(total_female_rev)
formatted_female_rev
# Out:
# '$361.94'

# %%
#find total number of unique ID's in SN
f_unique_sn = female_data_df["SN"].nunique()
f_unique_sn
# Out:
# 81

# %%
female_avg_ppp = total_female_rev/ f_unique_sn
formatted_female_avg_ppp = "${:,.2f}".format(female_avg_ppp)
formatted_female_avg_ppp
# Out:
# '$4.47'

# %%
nd_data_df = purchase_data_df.loc[purchase_data_df["Gender"] == "Other / Non-Disclosed",  :]
nd_data_df.head()
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
#
#                         Item Name  Price
# 9    Ghastly Adamantite Protector   3.58
# 22                  Warped Fetish   3.81
# 82                     Azurewrath   4.40
# 111                         Orbit   4.75
# 228                     Dreamsong   3.39

# %%
nd_avg_price = nd_data_df["Price"].mean()
formatted_nd_avg_price = "${:,.2f}".format(nd_avg_price)
formatted_nd_avg_price
# Out:
# '$3.35'

# %%
total_nd_rev = nd_data_df["Price"].sum()
formatted_nd_rev = "${:,.2f}".format(total_nd_rev)
formatted_nd_rev
# Out:
# '$50.19'

# %%
#find total number of unique ID's in SN
nd_unique_sn = nd_data_df["SN"].nunique()
nd_unique_sn
# Out:
# 11

# %%
nd_avg_ppp = total_nd_rev/ nd_unique_sn
formatted_nd_avg_ppp = "${:,.2f}".format(nd_avg_ppp)
formatted_nd_avg_ppp
# Out:
# '$4.56'

# %%
gender_purchase_summary = [{"Gender Selection": "Male", "Purchase Count": male_count, "Average Purchase Price": formatted_male_avg_price, "Total Purchase Value": formatted_male_rev, "Avg Total Purchase Per Person": formatted_male_avg_ppp}, {"Gender Selection": "Feale", "Purchase Count": female_count, "Average Purchase Price": formatted_female_avg_price, "Total Purchase Value": formatted_female_rev, "Avg Total Purchase Per Person": formatted_female_avg_ppp}, {"Gender Selection": "Other / Non-Disclosed", "Purchase Count": non_response_count, "Average Purchase Price": formatted_nd_avg_price, "Total Purchase Value": formatted_nd_rev, "Avg Total Purchase Per Person": formatted_nd_avg_ppp}]
gender_purchase_summary_df = pd.DataFrame(gender_purchase_summary)
gender_purchase_summary_df
# Out:
#         Gender Selection  Purchase Count Average Purchase Price  \
# 0                   Male             652                  $3.02
# 1                  Feale             113                  $3.20
# 2  Other / Non-Disclosed              15                  $3.35
#
#   Total Purchase Value Avg Total Purchase Per Person
# 0            $1,967.64                         $4.07
# 1              $361.94                         $4.47
# 2               $50.19                         $4.56

# %%
# Create the bins in which Data will be held   
bins = [0, 9, 14, 19, 24, 29, 34, 39, 40]

# Create the names for the five bins
age_groups = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
pd.cut(purchase_data_df["Age"], bins, labels=age_groups).head()
# Out:
# 0    20-24
# 1      40+
# 2    20-24
# 3    20-24
# 4    20-24
# Name: Age, dtype: category
# Categories (8, object): [<10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < 40+]

# %%
purchase_data_df["Age Bracket"] = pd.cut(purchase_data_df["Age"], bins, labels=age_groups, include_lowest=True)
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Bracket
# 0    Extraction, Quickblade Of Trembling Hands   3.53       20-24
# 1                            Frenzied Scimitar   1.56         40+
# 2                                 Final Critic   4.88       20-24
# 3                                  Blindscythe   3.27       20-24
# 4                                         Fury   1.44       20-24
# ..                                         ...    ...         ...
# 775                                       Wolf   3.54       20-24
# 776                           Exiled Doomblade   1.63       20-24
# 777      Celeste, Incarnation of the Corrupted   3.46       20-24
# 778                               Final Critic   4.19         <10
# 779                                       Dawn   4.60       20-24
#
# [780 rows x 8 columns]

# %%
age_groups = purchase_data_df.groupby("Age Bracket")
print(age_groups["Age"].count())
# Out:
# Age Bracket
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+        6
# Name: Age, dtype: int64

# %%
age_groups["Price"].mean()
# Out:
# Age Bracket
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.785000
# Name: Price, dtype: float64

# %%
age_groups["Price"].sum()
# Out:
# Age Bracket
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        16.71
# Name: Price, dtype: float64

# %%
tenorless_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "<10",  :]
tenorless_data_df.head()
# Out:
#     Purchase ID            SN  Age  Gender  Item ID  \
# 27           27       Eusri44    7    Male       96
# 33           33  Haillyrgue51    7    Male       44
# 37           37     Seuthep89    8    Male       73
# 78           78  Haillyrgue51    7    Male       50
# 81           81      Heudai45    8  Female      174
#
#                       Item Name  Price Age Bracket
# 27  Blood-Forged Skeletal Spine   3.09         <10
# 33        Bonecarvin Battle Axe   2.38         <10
# 37                  Ritual Mace   2.05         <10
# 78                         Dawn   4.60         <10
# 81              Primitive Blade   3.47         <10

# %%
tenorless_avg_price = tenorless_data_df["Price"].mean()
tenorless_avg_price = "${:,.2f}".format(tenorless_avg_price)
tenorless_avg_price
# Out:
# '$3.35'

# %%
tenorless_rev = tenorless_data_df["Price"].sum()
format_tenorless_rev = "${:,.2f}".format(tenorless_rev)
format_tenorless_rev
# Out:
# '$77.13'

# %%
tenorless_unique_sn = tenorless_data_df["SN"].nunique()
tenorless_unique_sn
# Out:
# 17

# %%
tenorless_avg_ppp = tenorless_rev/ tenorless_unique_sn
tenorless_avg_ppp = "${:,.2f}".format(tenorless_avg_ppp)
tenorless_avg_ppp
# Out:
# '$4.54'

# %%
tenfourteen_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "10-14",  :]
tenfourteen_data_df.head()
# Out:
#     Purchase ID          SN  Age  Gender  Item ID  \
# 26           26  Lirtossa84   11    Male       71
# 32           32  Aeralria27   10    Male      133
# 38           38    Reulae52   10  Female      116
# 54           54  Zhisrisu83   10    Male       25
# 56           56    Raesty92   12    Male      108
#
#                                     Item Name  Price Age Bracket
# 26                                     Demise   1.61       10-14
# 32                           Faith's Scimitar   4.09       10-14
# 38                    Renewed Skeletal Katana   4.18       10-14
# 54                                  Hero Cane   4.35       10-14
# 56  Extraction, Quickblade Of Trembling Hands   3.53       10-14

# %%
tenfourteen_avg_price = tenfourteen_data_df["Price"].mean()
tenfourteen_avg_price = "${:,.2f}".format(tenfourteen_avg_price)
tenfourteen_avg_price
# Out:
# '$2.96'

# %%
tenfourteen_rev = tenfourteen_data_df["Price"].sum()
format_tenfourteen_rev = "${:,.2f}".format(tenfourteen_rev)
format_tenfourteen_rev
# Out:
# '$82.78'

# %%
tenfourteen_unique_sn = tenfourteen_data_df["SN"].nunique()
tenfourteen_unique_sn
# Out:
# 22

# %%
tenfourteen_avg_ppp = tenfourteen_rev/ tenfourteen_unique_sn
tenfourteen_avg_ppp = "${:,.2f}".format(tenfourteen_avg_ppp)
tenfourteen_avg_ppp
# Out:
# '$3.76'

# %%
teen_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "15-19",  :]
teen_data_df.head()
# Out:
#     Purchase ID             SN  Age Gender  Item ID  \
# 30           30         Idai61   19   Male      140
# 34           34       Sondim73   19   Male      160
# 42           42  Aidaillodeu39   18   Male       72
# 59           59       Yaliru88   19   Male      105
# 61           61     Jiskimya77   17   Male      178
#
#                                        Item Name  Price Age Bracket
# 30                                       Striker   2.94       15-19
# 34                                    Azurewrath   4.40       15-19
# 42                                 Winter's Bite   3.77       15-19
# 59                  Hailstorm Shadowsteel Scythe   3.03       15-19
# 61  Oathbreaker, Last Hope of the Breaking Storm   4.23       15-19

# %%
teen_avg_price = teen_data_df["Price"].mean()
teen_avg_price = "${:,.2f}".format(teen_avg_price)
teen_avg_price
# Out:
# '$3.04'

# %%
teen_rev = teen_data_df["Price"].sum()
format_teen_rev = "${:,.2f}".format(teen_rev)
format_teen_rev
# Out:
# '$412.89'

# %%
teen_unique_sn = teen_data_df["SN"].nunique()
teen_unique_sn
# Out:
# 107

# %%
teen_avg_ppp = teen_rev/ teen_unique_sn
teen_avg_ppp = "${:,.2f}".format(teen_avg_ppp)
teen_avg_ppp
# Out:
# '$3.86'

# %%
earlytwenty_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "20-24",  :]
earlytwenty_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
# 5            5        Yalae81   22   Male       81
#
#                                    Item Name  Price Age Bracket
# 0  Extraction, Quickblade Of Trembling Hands   3.53       20-24
# 2                               Final Critic   4.88       20-24
# 3                                Blindscythe   3.27       20-24
# 4                                       Fury   1.44       20-24
# 5                                  Dreamkiss   3.61       20-24

# %%
earlytwenty_avg_price = earlytwenty_data_df["Price"].mean()
earlytwenty_avg_price = "${:,.2f}".format(earlytwenty_avg_price)
earlytwenty_avg_price
# Out:
# '$3.05'

# %%
earlytwenty_rev = earlytwenty_data_df["Price"].sum()
format_earlytwenty_rev = "${:,.2f}".format(earlytwenty_rev)
format_earlytwenty_rev
# Out:
# '$1,114.06'

# %%
earlytwenty_unique_sn = earlytwenty_data_df["SN"].nunique()
earlytwenty_unique_sn
# Out:
# 258

# %%
earlytwenty_avg_ppp = earlytwenty_rev/ earlytwenty_unique_sn
earlytwenty_avg_ppp = "${:,.2f}".format(earlytwenty_avg_ppp)
earlytwenty_avg_ppp
# Out:
# '$4.32'

# %%
latetwenty_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "25-29",  :]
latetwenty_data_df.head()
# Out:
#     Purchase ID            SN  Age  Gender  Item ID  \
# 25           25     Lisirra87   29    Male      178
# 46           46     Yasrisu92   27    Male      102
# 55           55     Phaelap26   25  Female       84
# 65           65  Chamirraya83   25    Male       34
# 70           70     Pheodai94   29    Male      143
#
#                                        Item Name  Price Age Bracket
# 25  Oathbreaker, Last Hope of the Breaking Storm   4.23       25-29
# 46                                       Avenger   3.44       25-29
# 55                                    Arcane Gem   3.79       25-29
# 65                               Retribution Axe   2.22       25-29
# 70                             Frenzied Scimitar   1.56       25-29

# %%
latetwenty_avg_price = latetwenty_data_df["Price"].mean()
latetwenty_avg_price = "${:,.2f}".format(latetwenty_avg_price)
latetwenty_avg_price
# Out:
# '$2.90'

# %%
latetwenty_rev = latetwenty_data_df["Price"].sum()
format_latetwenty_rev = "${:,.2f}".format(latetwenty_rev)
format_latetwenty_rev
# Out:
# '$293.00'

# %%
latetwenty_unique_sn = latetwenty_data_df["SN"].nunique()
latetwenty_unique_sn
# Out:
# 77

# %%
latetwenty_avg_ppp = latetwenty_rev/ latetwenty_unique_sn
latetwenty_avg_ppp = "${:,.2f}".format(latetwenty_avg_ppp)
latetwenty_avg_ppp
# Out:
# '$3.81'

# %%
earlythirty_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "30-34",  :]
earlythirty_data_df.head()
# Out:
#     Purchase ID           SN  Age Gender  Item ID  \
# 19           19    Chamalo71   30   Male       89
# 24           24      Siala43   30   Male      132
# 36           36   Idaisuir85   30   Male       76
# 49           49  Iaralrgue74   33   Male      110
# 53           53  Ilosianya35   32   Male      176
#
#                             Item Name  Price Age Bracket
# 19  Blazefury, Protector of Delusions   4.64       30-34
# 24                         Persuasion   3.19       30-34
# 36           Haunted Bronzed Bludgeon   3.15       30-34
# 49                         Suspension   1.44       30-34
# 53             Relentless Iron Skewer   2.84       30-34

# %%
earlythirty_avg_price = earlythirty_data_df["Price"].mean()
earlythirty_avg_price = "${:,.2f}".format(earlythirty_avg_price)
earlythirty_avg_price
# Out:
# '$2.93'

# %%
earlythirty_rev = earlythirty_data_df["Price"].sum()
format_earlythirty_rev = "${:,.2f}".format(earlythirty_rev)
format_earlythirty_rev
# Out:
# '$214.00'

# %%
earlythirty_unique_sn = earlythirty_data_df["SN"].nunique()
earlythirty_unique_sn
# Out:
# 52

# %%
earlythirty_avg_ppp = earlythirty_rev/ earlythirty_unique_sn
earlythirty_avg_ppp = "${:,.2f}".format(earlythirty_avg_ppp)
earlythirty_avg_ppp
# Out:
# '$4.12'

# %%
latethirty_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "35-39",  :]
latethirty_data_df.head()
# Out:
#     Purchase ID            SN  Age                 Gender  Item ID  \
# 6             6     Itheria73   36                   Male      169
# 9             9   Chanosian48   35  Other / Non-Disclosed      136
# 14           14   Saesrideu94   35                   Male      165
# 22           22  Siarithria38   38  Other / Non-Disclosed       24
# 31           31   Farusrian86   37                   Male      179
#
#                                  Item Name  Price Age Bracket
# 6   Interrogator, Blood Blade of the Queen   2.18       35-39
# 9             Ghastly Adamantite Protector   3.58       35-39
# 14             Bone Crushing Silver Skewer   4.86       35-39
# 22                           Warped Fetish   3.81       35-39
# 31         Wolf, Promise of the Moonwalker   4.48       35-39

# %%
latethirty_avg_price = latethirty_data_df["Price"].mean()
latethirty_avg_price = "${:,.2f}".format(latethirty_avg_price)
latethirty_avg_price
# Out:
# '$3.60'

# %%
latethirty_rev = latethirty_data_df["Price"].sum()
format_latethirty_rev = "${:,.2f}".format(latethirty_rev)
format_latethirty_rev
# Out:
# '$147.67'

# %%
latethirty_unique_sn = latethirty_data_df["SN"].nunique()
latethirty_unique_sn
# Out:
# 31

# %%
latethirty_avg_ppp = latethirty_rev/ latethirty_unique_sn
latethirty_avg_ppp = "${:,.2f}".format(latethirty_avg_ppp)
latethirty_avg_ppp
# Out:
# '$4.76'

# %%
old_data_df = purchase_data_df.loc[purchase_data_df["Age Bracket"] == "40+",  :]
old_data_df.head()
# Out:
#      Purchase ID           SN  Age Gender  Item ID  \
# 1              1  Lisovynya38   40   Male      143
# 23            23     Eyrian71   40   Male      151
# 156          156     Eyrian71   40   Male      117
# 220          220   Jiskjask85   40   Male       46
# 480          480    Salilis27   40   Male       59
#
#                              Item Name  Price Age Bracket
# 1                    Frenzied Scimitar   1.56         40+
# 23                           Severance   3.40         40+
# 156  Heartstriker, Legacy of the Light   1.79         40+
# 220            Hopeless Ebon Dualblade   1.33         40+
# 480      Lightning, Etcher of the King   4.23         40+

# %%
old_avg_price = old_data_df["Price"].mean()
old_avg_price = "${:,.2f}".format(old_avg_price)
old_avg_price
# Out:
# '$2.79'

# %%
old_rev = old_data_df["Price"].sum()
format_old_rev = "${:,.2f}".format(old_rev)
format_old_rev
# Out:
# '$16.71'

# %%
old_unique_sn = old_data_df["SN"].nunique()
old_unique_sn
# Out:
# 5

# %%
old_avg_ppp = old_rev/ old_unique_sn
old_avg_ppp = "${:,.2f}".format(old_avg_ppp)
old_avg_ppp
# Out:
# '$3.34'

# %%
tenorless = len(purchase_data_df[purchase_data_df["Age Bracket"] == "<10"])
tenorless
# Out:
# 23

# %%
tenfourteen = len(purchase_data_df[purchase_data_df["Age Bracket"] == "10-14"])
tenfourteen
# Out:
# 28

# %%
teen = len(purchase_data_df[purchase_data_df["Age Bracket"] == "15-19"])
teen
# Out:
# 136

# %%
earlytwenty = len(purchase_data_df[purchase_data_df["Age Bracket"] == "20-24"])
earlytwenty
# Out:
# 365

# %%
latetwenty = len(purchase_data_df[purchase_data_df["Age Bracket"] == "25-29"])
latetwenty
# Out:
# 101

# %%
earlythirty = len(purchase_data_df[purchase_data_df["Age Bracket"] == "30-34"])
earlythirty
# Out:
# 73

# %%
latethirty = len(purchase_data_df[purchase_data_df["Age Bracket"] == "35-39"])
latethirty
# Out:
# 41

# %%
old = len(purchase_data_df[purchase_data_df["Age Bracket"] == "40+"])
old
# Out:
# 6

# %%
age_summary = [{"Age Bracket": "<10", "Total Count": tenorless}, {"Age Bracket": "10-14", "Total Count": tenfourteen}, {"Age Bracket": "15-19", "Total Count": teen}, {"Age Bracket": "20-24", "Total Count": earlytwenty}, {"Age Bracket": "25-29", "Total Count": latetwenty}, {"Age Bracket": "30-34", "Total Count": earlythirty}, {"Age Bracket": "35-39", "Total Count": latethirty}, {"Age Bracket": "40+", "Total Count": old}] 
age_summary_df = pd.DataFrame(age_summary)
age_summary_df
# Out:
#   Age Bracket  Total Count
# 0         <10           23
# 1       10-14           28
# 2       15-19          136
# 3       20-24          365
# 4       25-29          101
# 5       30-34           73
# 6       35-39           41
# 7         40+            6

# %%
apct_summary = age_summary_df["Total Count"]/player_count
age_summary_df["Percentage of Players"] = apct_summary
age_summary_df
# Out:
#   Age Bracket  Total Count  Percentage of Players
# 0         <10           23               0.029487
# 1       10-14           28               0.035897
# 2       15-19          136               0.174359
# 3       20-24          365               0.467949
# 4       25-29          101               0.129487
# 5       30-34           73               0.093590
# 6       35-39           41               0.052564
# 7         40+            6               0.007692

# %%
age_summary_df = age_summary_df.style.format({'Percentage of Players': '{:.2%}'})
age_summary_df
# Out:
# <style  type="text/css" >
# </style><table id="T_73b750f6_bb3b_11ea_bfc5_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age Bracket</th>        <th class="col_heading level0 col1" >Total Count</th>        <th class="col_heading level0 col2" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row0_col0" class="data row0 col0" ><10</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row0_col1" class="data row0 col1" >23</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row0_col2" class="data row0 col2" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row1_col0" class="data row1 col0" >10-14</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row1_col1" class="data row1 col1" >28</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row1_col2" class="data row1 col2" >3.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row2_col0" class="data row2 col0" >15-19</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row2_col1" class="data row2 col1" >136</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row2_col2" class="data row2 col2" >17.44%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row3_col0" class="data row3 col0" >20-24</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row3_col1" class="data row3 col1" >365</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row3_col2" class="data row3 col2" >46.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row4_col0" class="data row4 col0" >25-29</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row4_col1" class="data row4 col1" >101</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row4_col2" class="data row4 col2" >12.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row5_col0" class="data row5 col0" >30-34</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row5_col1" class="data row5 col1" >73</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row5_col2" class="data row5 col2" >9.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row6_col0" class="data row6 col0" >35-39</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row6_col1" class="data row6 col1" >41</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row6_col2" class="data row6 col2" >5.26%</td>
#             </tr>
#             <tr>
#                         <th id="T_73b750f6_bb3b_11ea_bfc5_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row7_col0" class="data row7 col0" >40+</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row7_col1" class="data row7 col1" >6</td>
#                         <td id="T_73b750f6_bb3b_11ea_bfc5_acde48001122row7_col2" class="data row7 col2" >0.77%</td>
#             </tr>
#     </tbody></table>

# %%
age_trend_summary = [{"Age Bracket": "<10", "Purchase Count": tenorless, "Average Purchase Price": tenorless_avg_price, "Total Purchase Value": format_tenorless_rev, "Average Total Purchase Per Person": tenorless_avg_ppp},
                     {"Age Bracket": "10-14", "Purchase Count": tenfourteen, "Average Purchase Price": tenfourteen_avg_price, "Total Purchase Value": format_tenfourteen_rev, "Average Total Purchase Per Person": tenfourteen_avg_ppp}, 
                     {"Age Bracket": "15-19", "Purchase Count": teen, "Average Purchase Price": teen_avg_price, "Total Purchase Value": format_teen_rev, "Average Total Purchase Per Person": teen_avg_ppp}, 
                     {"Age Bracket": "20-24", "Purchase Count": earlytwenty, "Average Purchase Price": earlytwenty_avg_price, "Total Purchase Value": format_earlytwenty_rev, "Average Total Purchase Per Person": earlytwenty_avg_ppp}, 
                     {"Age Bracket": "25-29", "Purchase Count": latetwenty, "Average Purchase Price": latetwenty_avg_price, "Total Purchase Value": format_latetwenty_rev, "Average Total Purchase Per Person": latetwenty_avg_ppp}, 
                     {"Age Bracket": "30-34", "Purchase Count": earlythirty, "Average Purchase Price": earlythirty_avg_price, "Total Purchase Value": format_earlythirty_rev, "Average Total Purchase Per Person": earlythirty_avg_ppp}, 
                     {"Age Bracket": "35-39", "Purchase Count": latethirty, "Average Purchase Price": latethirty_avg_price, "Total Purchase Value": format_latethirty_rev, "Average Total Purchase Per Person": latethirty_avg_ppp}, 
                     {"Age Bracket": "40+", "Purchase Count": old, "Average Purchase Price": old_avg_price, "Total Purchase Value": format_old_rev, "Average Total Purchase Per Person": old_avg_ppp}] 
age_trend_summary_df = pd.DataFrame(age_trend_summary)
age_trend_summary_df
# Out:
#   Age Bracket  Purchase Count Average Purchase Price Total Purchase Value  \
# 0         <10              23                  $3.35               $77.13
# 1       10-14              28                  $2.96               $82.78
# 2       15-19             136                  $3.04              $412.89
# 3       20-24             365                  $3.05            $1,114.06
# 4       25-29             101                  $2.90              $293.00
# 5       30-34              73                  $2.93              $214.00
# 6       35-39              41                  $3.60              $147.67
# 7         40+               6                  $2.79               $16.71
#
#   Average Total Purchase Per Person
# 0                             $4.54
# 1                             $3.76
# 2                             $3.86
# 3                             $4.32
# 4                             $3.81
# 5                             $4.12
# 6                             $4.76
# 7                             $3.34

# %%
purchase_data_df["SN"].value_counts().head()
# Out:
# Lisosia93      5
# Idastidru52    4
# Iral74         4
# Zontibe81      3
# Hada39         3
# Name: SN, dtype: int64

# %%
High_Roller_1 = purchase_data_df[purchase_data_df["SN"] == "Lisosia93"]
High_Roller_1
# Out:
#      Purchase ID         SN  Age Gender  Item ID  \
# 74            74  Lisosia93   25   Male       89
# 120          120  Lisosia93   25   Male       24
# 224          224  Lisosia93   25   Male      157
# 603          603  Lisosia93   25   Male      132
# 609          609  Lisosia93   25   Male       40
#
#                              Item Name  Price Age Bracket
# 74   Blazefury, Protector of Delusions   4.64       25-29
# 120                      Warped Fetish   3.81       25-29
# 224            Spada, Etcher of Hatred   4.80       25-29
# 603                         Persuasion   3.19       25-29
# 609                      Second Chance   2.52       25-29

# %%
High_Roller_1_avg = purchase_data_df.loc[purchase_data_df["SN"] == "Lisosia93", "Price"].mean()
High_Roller_1_avg = "${:,.2f}".format(High_Roller_1_avg)
High_Roller_1_avg
# Out:
# '$3.79'

# %%
High_Roller_1_total = purchase_data_df.loc[purchase_data_df["SN"] == "Lisosia93", "Price"].sum()
High_Roller_1_total = "${:,.2f}".format(High_Roller_1_total)
High_Roller_1_total
# Out:
# '$18.96'

# %%
High_Roller_2 = purchase_data_df[purchase_data_df["SN"] == "Idastidru52"]
High_Roller_2
# Out:
#      Purchase ID           SN  Age Gender  Item ID  \
# 290          290  Idastidru52   24   Male      147
# 490          490  Idastidru52   24   Male      148
# 543          543  Idastidru52   24   Male      121
# 676          676  Idastidru52   24   Male      111
#
#                               Item Name  Price Age Bracket
# 290   Hellreaver, Heirloom of Inception   4.93       20-24
# 490  Warmonger, Gift of Suffering's End   4.03       20-24
# 543                            Massacre   1.60       20-24
# 676                        Misery's End   4.89       20-24

# %%
High_Roller_2_avg = purchase_data_df.loc[purchase_data_df["SN"] == "Idastidru52", "Price"].mean()
High_Roller_2_avg = "${:,.2f}".format(High_Roller_2_avg)
High_Roller_2_avg
# Out:
# '$3.86'

# %%
High_Roller_2_total = purchase_data_df.loc[purchase_data_df["SN"] == "Idastidru52", "Price"].sum()
High_Roller_2_total = "${:,.2f}".format(High_Roller_2_total)
High_Roller_2_total
# Out:
# '$15.45'

# %%
High_Roller_3 = purchase_data_df[purchase_data_df["SN"] == "Iral74"]
High_Roller_3
# Out:
#      Purchase ID      SN  Age Gender  Item ID  \
# 128          128  Iral74   21   Male       58
# 623          623  Iral74   21   Male      114
# 758          758  Iral74   21   Male      182
# 776          776  Iral74   21   Male      164
#
#                              Item Name  Price Age Bracket
# 128  Freak's Bite, Favor of Holy Might   4.14       20-24
# 623                 Yearning Mageblade   3.82       20-24
# 758                          Toothpick   4.03       20-24
# 776                   Exiled Doomblade   1.63       20-24

# %%
High_Roller_3_avg = purchase_data_df.loc[purchase_data_df["SN"] == "Iral74", "Price"].mean()
High_Roller_3_avg = "${:,.2f}".format(High_Roller_3_avg)
High_Roller_3_avg
# Out:
# '$3.40'

# %%
High_Roller_3_total = purchase_data_df.loc[purchase_data_df["SN"] == "Iral74", "Price"].sum()
High_Roller_3_total = "${:,.2f}".format(High_Roller_3_total)
High_Roller_3_total
# Out:
# '$13.62'

# %%
High_Roller_4 = purchase_data_df[purchase_data_df["SN"] == "Chamimla85"]
High_Roller_4
# Out:
#      Purchase ID          SN  Age Gender  Item ID  \
# 204          204  Chamimla85   16   Male        0
# 234          234  Chamimla85   16   Male       97
# 617          617  Chamimla85   16   Male       40
#
#                        Item Name  Price Age Bracket
# 204                     Splinter   1.28       15-19
# 234  Swan Song, Gouger Of Terror   2.50       15-19
# 617                Second Chance   2.52       15-19

# %%
High_Roller_4_avg = purchase_data_df.loc[purchase_data_df["SN"] == "Chamimla85", "Price"].mean()
High_Roller_4_avg = "${:,.2f}".format(High_Roller_4_avg)
High_Roller_4_avg
# Out:
# '$2.10'

# %%
High_Roller_4_total = purchase_data_df.loc[purchase_data_df["SN"] == "Chamimla85", "Price"].sum()
High_Roller_4_total = "${:,.2f}".format(High_Roller_4_total)
High_Roller_4_total
# Out:
# '$6.30'

# %%
High_Roller_5 = purchase_data_df[purchase_data_df["SN"] == "Idai61"]
High_Roller_5
# Out:
#      Purchase ID      SN  Age Gender  Item ID            Item Name  Price  \
# 30            30  Idai61   19   Male      140              Striker   2.94
# 370          370  Idai61   19   Male       45  Glinting Glass Edge   3.85
# 407          407  Idai61   19   Male      131                 Fury   1.44
#
#     Age Bracket
# 30        15-19
# 370       15-19
# 407       15-19

# %%
High_Roller_5_avg = purchase_data_df.loc[purchase_data_df["SN"] == "Idai61", "Price"].mean()
High_Roller_5_avg = "${:,.2f}".format(High_Roller_5_avg)
High_Roller_5_avg
# Out:
# '$2.74'

# %%
High_Roller_5_total = purchase_data_df.loc[purchase_data_df["SN"] == "Idai61", "Price"].sum()
High_Roller_5_total = "${:,.2f}".format(High_Roller_5_total)
High_Roller_5_total
# Out:
# '$8.23'

# %%
new_index_purchase_data_df = purchase_data_df.set_index("SN")
new_index_purchase_data_df
# Out:
#                Purchase ID  Age  Gender  Item ID  \
# SN
# Lisim78                  0   20    Male      108
# Lisovynya38              1   40    Male      143
# Ithergue48               2   24    Male       92
# Chamassasya86            3   24    Male      100
# Iskosia90                4   23    Male      131
# ...                    ...  ...     ...      ...
# Aethedru70             775   21  Female       60
# Iral74                 776   21    Male      164
# Yathecal72             777   20    Male       67
# Sisur91                778    7    Male       92
# Ennrian78              779   24    Male       50
#
#                                                Item Name  Price Age Bracket
# SN
# Lisim78        Extraction, Quickblade Of Trembling Hands   3.53       20-24
# Lisovynya38                            Frenzied Scimitar   1.56         40+
# Ithergue48                                  Final Critic   4.88       20-24
# Chamassasya86                                Blindscythe   3.27       20-24
# Iskosia90                                           Fury   1.44       20-24
# ...                                                  ...    ...         ...
# Aethedru70                                          Wolf   3.54       20-24
# Iral74                                  Exiled Doomblade   1.63       20-24
# Yathecal72         Celeste, Incarnation of the Corrupted   3.46       20-24
# Sisur91                                     Final Critic   4.19         <10
# Ennrian78                                           Dawn   4.60       20-24
#
# [780 rows x 7 columns]

# %%
new_index_purchase_data_df = new_index_purchase_data_df.sort_values("SN", ascending=False)
new_index_purchase_data_df
# Out:
#               Purchase ID  Age  Gender  Item ID  \
# SN
# Zontibe81              17   21    Male      161
# Zontibe81             442   21    Male       84
# Zontibe81             560   21    Male        2
# Zhisrisu83            141   10    Male       60
# Zhisrisu83             54   10    Male       25
# ...                   ...  ...     ...      ...
# Aelaria33             630   23    Male      171
# Aela59                 28   21    Male      119
# Aeda94                388   17    Male      128
# Adastirin33           142   35  Female      175
# Adairialis76          467   16    Male      123
#
#                                               Item Name  Price Age Bracket
# SN
# Zontibe81                                        Devine   1.76       20-24
# Zontibe81                                    Arcane Gem   3.79       20-24
# Zontibe81                                       Verdict   2.48       20-24
# Zhisrisu83                                         Wolf   3.54       10-14
# Zhisrisu83                                    Hero Cane   4.35       10-14
# ...                                                 ...    ...         ...
# Aelaria33                                       Scalpel   1.79       20-24
# Aela59        Stormbringer, Dark Blade of Ending Misery   4.32       20-24
# Aeda94                    Blazeguard, Reach of Eternity   4.91       15-19
# Adastirin33                  Woeful Adamantite Claymore   4.48       35-39
# Adairialis76                          Twilight's Carver   2.28       15-19
#
# [780 rows x 7 columns]

# %%
sn_counts = purchase_data_df["SN"].value_counts()
sn_counts
# Out:
# Lisosia93        5
# Idastidru52      4
# Iral74           4
# Zontibe81        3
# Hada39           3
#                 ..
# Yalostiphos68    1
# Lisjaskya84      1
# Tyaedainu44      1
# Chamastya76      1
# Mindossa76       1
# Name: SN, Length: 576, dtype: int64

# %%
grouped_sn_counts_df = purchase_data_df.groupby(["SN"])
print(grouped_sn_counts_df)
grouped_sn_counts_df.count().head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7feb97b272b0>
#               Purchase ID  Age  Gender  Item ID  Item Name  Price  Age Bracket
# SN
# Adairialis76            1    1       1        1          1      1            1
# Adastirin33             1    1       1        1          1      1            1
# Aeda94                  1    1       1        1          1      1            1
# Aela59                  1    1       1        1          1      1            1
# Aelaria33               1    1       1        1          1      1            1

# %%
grouped_sn_counts_df["SN"].sum()
# Out:
# SN
# Adairialis76                       Adairialis76
# Adastirin33                         Adastirin33
# Aeda94                                   Aeda94
# Aela59                                   Aela59
# Aelaria33                             Aelaria33
#                               ...
# Yathecal82       Yathecal82Yathecal82Yathecal82
# Yathedeu43                 Yathedeu43Yathedeu43
# Yoishirrala98                     Yoishirrala98
# Zhisrisu83                 Zhisrisu83Zhisrisu83
# Zontibe81           Zontibe81Zontibe81Zontibe81
# Name: SN, Length: 576, dtype: object

# %%
df1 = pd.DataFrame({"Number of Purchases": sn_counts})
df1
# Out:
#                Number of Purchases
# Lisosia93                        5
# Idastidru52                      4
# Iral74                           4
# Zontibe81                        3
# Hada39                           3
# ...                            ...
# Yalostiphos68                    1
# Lisjaskya84                      1
# Tyaedainu44                      1
# Chamastya76                      1
# Mindossa76                       1
#
# [576 rows x 1 columns]

# %%
group_cols = purchase_data_df.columns.tolist()
group_cols
# Out:
# ['Purchase ID',
#  'SN',
#  'Age',
#  'Gender',
#  'Item ID',
#  'Item Name',
#  'Price',
#  'Age Bracket']

# %%
total_purchase = purchase_data_df.groupby(['SN']).agg({'Price': 'sum'})
total_purchase
# Out:
#                Price
# SN
# Adairialis76    2.28
# Adastirin33     4.48
# Aeda94          4.91
# Aela59          4.32
# Aelaria33       1.79
# ...              ...
# Yathecal82      6.22
# Yathedeu43      6.02
# Yoishirrala98   4.58
# Zhisrisu83      7.89
# Zontibe81       8.03
#
# [576 rows x 1 columns]

# %%
high_rollers_df = df1.join(total_purchase)
high_rollers_df
# Out:
#                Number of Purchases  Price
# Lisosia93                        5  18.96
# Idastidru52                      4  15.45
# Iral74                           4  13.62
# Zontibe81                        3   8.03
# Hada39                           3   8.57
# ...                            ...    ...
# Yalostiphos68                    1   4.40
# Lisjaskya84                      1   2.89
# Tyaedainu44                      1   3.54
# Chamastya76                      1   2.05
# Mindossa76                       1   4.93
#
# [576 rows x 2 columns]

# %%
high_rollers_avg = high_rollers_df["Price"]/sn_counts
high_rollers_df["Average Purchase Price"] = high_rollers_avg
high_rollers_df
# Out:
#                Number of Purchases  Price  Average Purchase Price
# Lisosia93                        5  18.96                3.792000
# Idastidru52                      4  15.45                3.862500
# Iral74                           4  13.62                3.405000
# Zontibe81                        3   8.03                2.676667
# Hada39                           3   8.57                2.856667
# ...                            ...    ...                     ...
# Yalostiphos68                    1   4.40                4.400000
# Lisjaskya84                      1   2.89                2.890000
# Tyaedainu44                      1   3.54                3.540000
# Chamastya76                      1   2.05                2.050000
# Mindossa76                       1   4.93                4.930000
#
# [576 rows x 3 columns]

# %%
high_rollers_df = high_rollers_df.style.format({"Price": "${:,.2f}"})
high_rollers_df
# Out:
# <style  type="text/css" >
# </style><table id="T_7c008692_bb3b_11ea_9913_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Purchases</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Average Purchase Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row0_col1" class="data row0 col1" >$18.96</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row0_col2" class="data row0 col2" >3.792000</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row1_col1" class="data row1 col1" >$15.45</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row1_col2" class="data row1 col2" >3.862500</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row2" class="row_heading level0 row2" >Iral74</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row2_col1" class="data row2 col1" >$13.62</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row2_col2" class="data row2 col2" >3.405000</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row3" class="row_heading level0 row3" >Zontibe81</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row3_col1" class="data row3 col1" >$8.03</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row3_col2" class="data row3 col2" >2.676667</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row4" class="row_heading level0 row4" >Hada39</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row4_col1" class="data row4 col1" >$8.57</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row4_col2" class="data row4 col2" >2.856667</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row5" class="row_heading level0 row5" >Lisopela58</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row5_col0" class="data row5 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row5_col1" class="data row5 col1" >$8.86</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row5_col2" class="data row5 col2" >2.953333</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row6" class="row_heading level0 row6" >Strithenu87</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row6_col0" class="data row6 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row6_col1" class="data row6 col1" >$10.18</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row6_col2" class="data row6 col2" >3.393333</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row7" class="row_heading level0 row7" >Saedaiphos46</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row7_col0" class="data row7 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row7_col1" class="data row7 col1" >$8.83</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row7_col2" class="data row7 col2" >2.943333</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row8" class="row_heading level0 row8" >Aina42</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row8_col0" class="data row8 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row8_col1" class="data row8 col1" >$9.22</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row8_col2" class="data row8 col2" >3.073333</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row9" class="row_heading level0 row9" >Yathecal82</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row9_col0" class="data row9 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row9_col1" class="data row9 col1" >$6.22</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row9_col2" class="data row9 col2" >2.073333</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row10" class="row_heading level0 row10" >Lassilsala30</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row10_col0" class="data row10 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row10_col1" class="data row10 col1" >$11.51</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row10_col2" class="data row10 col2" >3.836667</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row11" class="row_heading level0 row11" >Chamjask73</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row11_col0" class="data row11 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row11_col1" class="data row11 col1" >$13.83</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row11_col2" class="data row11 col2" >4.610000</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row12" class="row_heading level0 row12" >Rarallo90</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row12_col0" class="data row12 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row12_col1" class="data row12 col1" >$9.05</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row12_col2" class="data row12 col2" >3.016667</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row13" class="row_heading level0 row13" >Siallylis44</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row13_col0" class="data row13 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row13_col1" class="data row13 col1" >$10.37</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row13_col2" class="data row13 col2" >3.456667</td>
#             </tr>
#             <tr>
#                         <th id="T_7c008692_bb3b_11ea_9913_acde48001122level0_row14" class="row_heading level0 row14" >Aelin32</th>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row14_col0" class="data row14 col0" >3</td>
#                         <td id="T_7c008692_bb3b_11ea_9913_acde48001122row14_col1" class="data row14 col1" >$8.98</td>
#                         <td

# %%
high_rollers_df2 = high_rollers_df.format({"Average Purchase Price": "${:,.2f}"})
high_rollers_df2
# Out:
# <style  type="text/css" >
# </style><table id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Purchases</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Average Purchase Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row0_col1" class="data row0 col1" >$18.96</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row0_col2" class="data row0 col2" >$3.79</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row1_col1" class="data row1 col1" >$15.45</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row1_col2" class="data row1 col2" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row2" class="row_heading level0 row2" >Iral74</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row2_col1" class="data row2 col1" >$13.62</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row2_col2" class="data row2 col2" >$3.40</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row3" class="row_heading level0 row3" >Zontibe81</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row3_col1" class="data row3 col1" >$8.03</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row3_col2" class="data row3 col2" >$2.68</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row4" class="row_heading level0 row4" >Hada39</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row4_col1" class="data row4 col1" >$8.57</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row4_col2" class="data row4 col2" >$2.86</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row5" class="row_heading level0 row5" >Lisopela58</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row5_col0" class="data row5 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row5_col1" class="data row5 col1" >$8.86</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row5_col2" class="data row5 col2" >$2.95</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row6" class="row_heading level0 row6" >Strithenu87</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row6_col0" class="data row6 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row6_col1" class="data row6 col1" >$10.18</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row6_col2" class="data row6 col2" >$3.39</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row7" class="row_heading level0 row7" >Saedaiphos46</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row7_col0" class="data row7 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row7_col1" class="data row7 col1" >$8.83</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row7_col2" class="data row7 col2" >$2.94</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row8" class="row_heading level0 row8" >Aina42</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row8_col0" class="data row8 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row8_col1" class="data row8 col1" >$9.22</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row8_col2" class="data row8 col2" >$3.07</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row9" class="row_heading level0 row9" >Yathecal82</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row9_col0" class="data row9 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row9_col1" class="data row9 col1" >$6.22</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row9_col2" class="data row9 col2" >$2.07</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row10" class="row_heading level0 row10" >Lassilsala30</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row10_col0" class="data row10 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row10_col1" class="data row10 col1" >$11.51</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row10_col2" class="data row10 col2" >$3.84</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row11" class="row_heading level0 row11" >Chamjask73</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row11_col0" class="data row11 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row11_col1" class="data row11 col1" >$13.83</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row11_col2" class="data row11 col2" >$4.61</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row12" class="row_heading level0 row12" >Rarallo90</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row12_col0" class="data row12 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row12_col1" class="data row12 col1" >$9.05</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row12_col2" class="data row12 col2" >$3.02</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row13" class="row_heading level0 row13" >Siallylis44</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row13_col0" class="data row13 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row13_col1" class="data row13 col1" >$10.37</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row13_col2" class="data row13 col2" >$3.46</td>
#             </tr>
#             <tr>
#                         <th id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122level0_row14" class="row_heading level0 row14" >Aelin32</th>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row14_col0" class="data row14 col0" >3</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122row14_col1" class="data row14 col1" >$8.98</td>
#                         <td id="T_7c5e89d8_bb3b_11ea_a3e0_acde48001122

# %%
id_counts = purchase_data_df["Item ID"].value_counts()
id_counts
# Out:
# 92     13
# 178    12
# 108     9
# 132     9
# 82      9
#        ..
# 104     1
# 27      1
# 134     1
# 118     1
# 91      1
# Name: Item ID, Length: 179, dtype: int64

# %%
grouped_id_counts_df = purchase_data_df.groupby(["Item ID", "Item Name"])
print(grouped_id_counts_df)
grouped_id_counts_df.count().head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7feb979ddcc0>
#                             Purchase ID  SN  Age  Gender  Price  Age Bracket
# Item ID Item Name
# 0       Splinter                      4   4    4       4      4            4
# 1       Crucifer                      4   4    4       4      4            4
# 2       Verdict                       6   6    6       6      6            6
# 3       Phantomlight                  6   6    6       6      6            6
# 4       Bloodlord's Fetish            5   5    5       5      5            5

# %%
grouped_id_counts_df["Item ID"].sum()
# Out:
# Item ID  Item Name
# 0        Splinter                                           0
# 1        Crucifer                                           4
# 2        Verdict                                           12
# 3        Phantomlight                                      18
# 4        Bloodlord's Fetish                                20
#                                                          ...
# 178      Oathbreaker, Last Hope of the Breaking Storm    2136
# 179      Wolf, Promise of the Moonwalker                 1074
# 181      Reaper's Toll                                    905
# 182      Toothpick                                        546
# 183      Dragon's Greatsword                              549
# Name: Item ID, Length: 179, dtype: int64

# %%
id_count_df = pd.DataFrame({"Number of Purchases": id_counts})
id_count_df
# Out:
#      Number of Purchases
# 92                    13
# 178                   12
# 108                    9
# 132                    9
# 82                     9
# ..                   ...
# 104                    1
# 27                     1
# 134                    1
# 118                    1
# 91                     1
#
# [179 rows x 1 columns]

# %%
total_item_purchase = purchase_data_df.groupby(['Item ID']).agg({'Price': 'sum'})
total_item_purchase
# Out:
#          Price
# Item ID
# 0         5.12
# 1        11.77
# 2        14.88
# 3        14.94
# 4         8.50
# ...        ...
# 178      50.76
# 179      26.88
# 181       8.30
# 182      12.09
# 183       3.27
#
# [179 rows x 1 columns]

# %%
purchase_df = id_count_df.join(total_item_purchase)
purchase_df
# Out:
#      Number of Purchases  Price
# 92                    13  59.99
# 178                   12  50.76
# 108                    9  31.77
# 132                    9  28.99
# 82                     9  44.10
# ..                   ...    ...
# 104                    1   1.93
# 27                     1   3.30
# 134                    1   4.50
# 118                    1   2.17
# 91                     1   4.17
#
# [179 rows x 2 columns]

# %%
purchase_df_avg = purchase_df["Price"]/id_counts
purchase_df["Average Purchase Price"] = purchase_df_avg
purchase_df
# Out:
#      Number of Purchases  Price  Average Purchase Price
# 92                    13  59.99                4.614615
# 178                   12  50.76                4.230000
# 108                    9  31.77                3.530000
# 132                    9  28.99                3.221111
# 82                     9  44.10                4.900000
# ..                   ...    ...                     ...
# 104                    1   1.93                1.930000
# 27                     1   3.30                3.300000
# 134                    1   4.50                4.500000
# 118                    1   2.17                2.170000
# 91                     1   4.17                4.170000
#
# [179 rows x 3 columns]

# %%
purchase_df = purchase_df.style.format({"Price": "${:,.2f}"})
purchase_df
# Out:
# <style  type="text/css" >
# </style><table id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Purchases</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Average Purchase Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row0" class="row_heading level0 row0" >92</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row0_col1" class="data row0 col1" >$59.99</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row0_col2" class="data row0 col2" >4.614615</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row1" class="row_heading level0 row1" >178</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row1_col1" class="data row1 col1" >$50.76</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row1_col2" class="data row1 col2" >4.230000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row2" class="row_heading level0 row2" >108</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row2_col1" class="data row2 col1" >$31.77</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row2_col2" class="data row2 col2" >3.530000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row3" class="row_heading level0 row3" >132</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row3_col1" class="data row3 col1" >$28.99</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row3_col2" class="data row3 col2" >3.221111</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row4" class="row_heading level0 row4" >82</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row4_col1" class="data row4 col1" >$44.10</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row4_col2" class="data row4 col2" >4.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row5" class="row_heading level0 row5" >145</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row5_col1" class="data row5 col1" >$41.22</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row5_col2" class="data row5 col2" >4.580000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row6" class="row_heading level0 row6" >60</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row6_col0" class="data row6 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row6_col1" class="data row6 col1" >$28.32</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row6_col2" class="data row6 col2" >3.540000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row7_col1" class="data row7 col1" >$17.76</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row7_col2" class="data row7 col2" >2.220000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row8" class="row_heading level0 row8" >37</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row8_col1" class="data row8 col1" >$25.28</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row8_col2" class="data row8 col2" >3.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row9" class="row_heading level0 row9" >59</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row9_col0" class="data row9 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row9_col1" class="data row9 col1" >$33.84</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row9_col2" class="data row9 col2" >4.230000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row10" class="row_heading level0 row10" >72</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row10_col0" class="data row10 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row10_col1" class="data row10 col1" >$30.16</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row10_col2" class="data row10 col2" >3.770000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row11" class="row_heading level0 row11" >19</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row11_col0" class="data row11 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row11_col1" class="data row11 col1" >$8.16</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row11_col2" class="data row11 col2" >1.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row12" class="row_heading level0 row12" >103</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row12_col0" class="data row12 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row12_col1" class="data row12 col1" >$34.80</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row12_col2" class="data row12 col2" >4.350000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row13" class="row_heading level0 row13" >75</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row13_col0" class="data row13 col0" >8</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row13_col1" class="data row13 col1" >$19.36</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row13_col2" class="data row13 col2" >2.420000</td>
#             </tr>
#             <tr>
#                         <th id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122level0_row14" class="row_heading level0 row14" >117</th>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row14_col0" class="data row14 col0" >7</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row14_col1" class="data row14 col1" >$12.53</td>
#                         <td id="T_4b6b9c50_bb3c_11ea_abfa_acde48001122row14_col2" class="data row14 col2" >1.790000</td>

# %%
purchase_df = purchase_df.format({"Average Purchase Price": "${:,.2f}"})
purchase_df
# Out:
# <style  type="text/css" >
# </style><table id="T_4ce99550_bb3c_11ea_81d1_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Purchases</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Average Purchase Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row0" class="row_heading level0 row0" >92</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row0_col1" class="data row0 col1" >$59.99</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row0_col2" class="data row0 col2" >$4.61</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row1" class="row_heading level0 row1" >178</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row1_col1" class="data row1 col1" >$50.76</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row1_col2" class="data row1 col2" >$4.23</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row2" class="row_heading level0 row2" >108</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row2_col1" class="data row2 col1" >$31.77</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row2_col2" class="data row2 col2" >$3.53</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row3" class="row_heading level0 row3" >132</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row3_col1" class="data row3 col1" >$28.99</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row3_col2" class="data row3 col2" >$3.22</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row4" class="row_heading level0 row4" >82</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row4_col1" class="data row4 col1" >$44.10</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row4_col2" class="data row4 col2" >$4.90</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row5" class="row_heading level0 row5" >145</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row5_col1" class="data row5 col1" >$41.22</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row5_col2" class="data row5 col2" >$4.58</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row6" class="row_heading level0 row6" >60</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row6_col0" class="data row6 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row6_col1" class="data row6 col1" >$28.32</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row6_col2" class="data row6 col2" >$3.54</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row7_col1" class="data row7 col1" >$17.76</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row7_col2" class="data row7 col2" >$2.22</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row8" class="row_heading level0 row8" >37</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row8_col1" class="data row8 col1" >$25.28</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row8_col2" class="data row8 col2" >$3.16</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row9" class="row_heading level0 row9" >59</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row9_col0" class="data row9 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row9_col1" class="data row9 col1" >$33.84</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row9_col2" class="data row9 col2" >$4.23</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row10" class="row_heading level0 row10" >72</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row10_col0" class="data row10 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row10_col1" class="data row10 col1" >$30.16</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row10_col2" class="data row10 col2" >$3.77</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row11" class="row_heading level0 row11" >19</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row11_col0" class="data row11 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row11_col1" class="data row11 col1" >$8.16</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row11_col2" class="data row11 col2" >$1.02</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row12" class="row_heading level0 row12" >103</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row12_col0" class="data row12 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row12_col1" class="data row12 col1" >$34.80</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row12_col2" class="data row12 col2" >$4.35</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row13" class="row_heading level0 row13" >75</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row13_col0" class="data row13 col0" >8</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row13_col1" class="data row13 col1" >$19.36</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row13_col2" class="data row13 col2" >$2.42</td>
#             </tr>
#             <tr>
#                         <th id="T_4ce99550_bb3c_11ea_81d1_acde48001122level0_row14" class="row_heading level0 row14" >117</th>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row14_col0" class="data row14 col0" >7</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row14_col1" class="data row14 col1" >$12.53</td>
#                         <td id="T_4ce99550_bb3c_11ea_81d1_acde48001122row14_col2" class="data row14 col2" >$1.79</td>
#             </tr>
#             <tr>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-ea59e17aed72> in <module>
# ----> 1 purchase_df = purchase_df.sort_values("Number of Purchases", ascending=False)
#       2 purchase_df
#
# AttributeError: 'Styler' object has no attribute 'sort_values'
